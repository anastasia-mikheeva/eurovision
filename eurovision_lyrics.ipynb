# %%
import tensorflow as tf
from tensorflow.compat.v1.train import AdamOptimizer
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.callbacks import LambdaCallback, ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, LSTM, Embedding, BatchNormalization, Bidirectional
from tensorflow.keras.utils import get_file, to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import categorical_accuracy
import numpy as np
import pickle
import random
import sys
import io
import os

sys.path.append('/.')  # add parent directory to Python path for layers.py access
from AttentionWithContext import AttentionWithContext

# %%
# Import pickled text corpus and text tokenizer:
# This 

with open ('./corpus_eng_new', 'rb') as fp:
    corpus_tokenized = pickle.load(fp)

with open ('./tokenizer_new', 'rb') as fp:
    word_tokenizer = pickle.load(fp)

# %%
def generate_train_dataset(window, tokenized_corpus=corpus_tokenized):
    """
    A function to create training data of set sequence length WINDOW from a tokenized corpus.
    Inputs: 
    window is an integer (must be smaller than the lengths of all songs in the corpus)
    tokenized_corpus is a list of songs and each song is a list of tokens
    
    Outputs: 
    X is an array of width WINDOW-1 corresponding to sequences of that length.
    y is an array of width 1 corresponding to each next token after the last token in each sequence in X.
    """
    train_data = []
    train_label = []
    for song in tokenized_corpus:
        len_song = len(song)        
        for i in range(0,len_song-window+1):
            train_data.append(song[i:i+window-1])
            train_label.append(song[i+window-1])
    return np.array(train_data), np.array(train_label)

# %%
WINDOW = 15
VOCAB_SIZE = len(word_tokenizer.word_index)

# %%
X, y = generate_train_dataset(WINDOW)

# %%
# Create dictionaries for unique indices given to each word in vocab
word2num = word_tokenizer.word_index
num2word = {v:k for k, v in word2num.items()}

# %%
# Manually convert 2D X to array of numerical indices

def words2seq (array, dictionary=word2num):
  new_array=np.zeros(array.shape)
  for i in range(array.shape[0]):
      for j in range(array.shape[1]):
        new_array[i][j] = dictionary[array[i][j]]
  new_array = new_array.astype(int)     
  return new_array

# %%
# convert 1D y array to numbers
def words2seq_flat (array, dictionary=word2num):
  new_array=np.zeros(array.shape)
  for i in range(array.shape[0]):
      if array[i] in dictionary.keys():
        new_array[i] = dictionary[array[i]]
      else:
        new_array[i] = 0
  new_array = new_array.astype(int)                          
  return new_array

# %%
# Converts X and y from strings to numerical equivalents 
Xnum = words2seq(X)
ynum= words2seq_flat(y)

# %%
def is_word_in_dict(words, word_index=word2num.keys()):
  """
  Takes either a string or a numpy array of words as input and checks if each 
  word is in the given word index.
  """
  if type(words) == 'str':
    for word in words.split():
      if word not in word_index:
          return False
  elif type(words) == 'np.ndarray':
    for word in words:
      if word not in word_index:
          return False
  return True

# %%
def string_to_vec(string, dict=word2num):
  """
  Converts a string to a vector using the given word index dictionary
  """
  return np.array([word2num[word] for word in string.split()])

# %%
embeddings_index = dict()
f = open('./glove.6B.100d.txt')

for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs

f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400001 word vectors.

# %%
# create a weight matrix for words in training docs
embedding_matrix = np.zeros((VOCAB_SIZE+1, 100))

for word, i in word_tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
# CALLBACK FUNCTIONS
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "training_2/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=0, 
    save_weights_only=True,
    save_freq=5)

# Callback function for early stopping
es_callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.002, patience=3, verbose=10)

# Callback function for printing model predictions with seed every 3 epochs
def on_epoch_end(epoch, logs, Xnum=Xnum):
    # Function invoked at end of each epoch. Prints generated text.
    if epoch % 3 != 0:
        return
    # create a seed
    seed_all = [word2num[word] for word in ['all', 'i', 'want', 'is', 'peace', 'and', 'love']]
    seed = seed_all
    seed = " ".join(num2word[num] for num in seed)
    #generated = seed
    generated= ''
    print(f'\nGenerating text after Epoch: {epoch} with seed: \n{seed}\n')
    sys.stdout.write(generated)

    generated = generate_song(seed)

    sys.stdout.write(generated+'\n')
    sys.stdout.flush()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
X_input = Xnum
y_input = to_categorical(ynum,VOCAB_SIZE+1)
EMBEDDING_DIMS = 100
NUM_EPOCHS = 200
BATCH_SIZE = 500
callbacks= [cp_callback, es_callback, print_callback]
adam = AdamOptimizer()

# %%
model = Sequential()

#embedding layer with pretrained vectors, not trainable
model.add(Embedding(VOCAB_SIZE+1,100,weights=[embedding_matrix],input_length=WINDOW-1,trainable=False))
model.add(BatchNormalization())
model.add(Bidirectional(LSTM(10, dropout=0.4, return_sequences=True)))
model.add(AttentionWithContext())
model.add(Dense(100, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(VOCAB_SIZE+1, activation='softmax')) 
# vocab_size +1 to avoid out of bound
# compile the model
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics='accuracy')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 14, 100)           519100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 100)           400
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 14, 20)            8880
# _________________________________________________________________
# attention_with_context_1 (At (None, 20)                440
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               2100
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 100)               400
# _________________________________________________________________
# dense_3 (Dense)              (None, 5191)              524291
# =================================================================
# Total params: 1,055,611
# Trainable params: 536,111
# Non-trainable params: 519,500
# _________________________________________________________________

# %%
def generate_song(seed, model=model, index_word=word_tokenizer.index_word , word_index=word_tokenizer.word_index, vocab_size=VOCAB_SIZE, generated_length=50):
    """
    A function to generate a song of a given token length for a given imput and model
    """
    string_returned = seed
    if is_word_in_dict(seed, word_index):
      X = string_to_vec(seed)
      counter = 1
      
      #print(string_returned)
 
      for i in range(generated_length):
          y_pred = model.predict(X)
          pred_choice = random.choices(range(1,vocab_size+1), weights=y_pred[-1][:-1], k=1)
          word_predict = num2word[pred_choice[0]]
          #print(word_predict)
          string_returned += " " + word_predict
          #print(string_returned)
          X = ' '.join(string_returned.split()[counter:])
          #print(X)
          X = np.array([word2num[word] for word in X if word in word2num.keys()])
          counter += 1
      return string_returned

# %%
history = model.fit(X_input, y_input, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS, callbacks=callbacks, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/200
# 258/258 [==============================] - ETA: 0s - loss: 6.9876 - accuracy: 0.0503
# Generating text after Epoch: 0 with seed:
# all i want is peace and love
#
# WARNING:tensorflow:Model was constructed with shape (None, 14) for input Tensor("embedding_1_input:0", shape=(None, 14), dtype=float32), but it was called on an input with incompatible shape (None, 1).
# WARNING:tensorflow:Model was constructed with shape (None, 14) for input Tensor("embedding_1_input:0", shape=(None, 14), dtype=float32), but it was called on an input with incompatible shape (32, 1).
# all i want is peace and love echoes lesson under he's my wild stones fix beat beautiful victims find salvation own spotlight howling day glory pump ooh nightmares every popular sometimes ride popular code w bras grab life after spend read return become you've does popular take faster lips oh-oh as down you've glory called getting as
# 258/258 [==============================] - 15s 58ms/step - loss: 6.9876 - accuracy: 0.0503 - val_loss: 6.2203 - val_accuracy: 0.0470
# Epoch 2/200
# 258/258 [==============================] - 11s 43ms/step - loss: 5.6029 - accuracy: 0.0704 - val_loss: 5.8810 - val_accuracy: 0.0619
# Epoch 3/200
# 258/258 [==============================] - 11s 41ms/step - loss: 5.2368 - accuracy: 0.0877 - val_loss: 5.7235 - val_accuracy: 0.0761
# Epoch 4/200
# 256/258 [============================>.] - ETA: 0s - loss: 5.0334 - accuracy: 0.1014
# Generating text after Epoch: 3 with seed:
# all i want is peace and love
#
# all i want is peace and love oh ti dance really long flame ti la eternally long flame own forgotten really scared own reality god really it's flame ti know keeps flame really own lights somewhere own breathe own ti knew the had the own reality hold reality everyone world's flame really long my don't reality left
# 258/258 [==============================] - 12s 48ms/step - loss: 5.0334 - accuracy: 0.1016 - val_loss: 5.6794 - val_accuracy: 0.0831
# Epoch 5/200
# 258/258 [==============================] - 11s 41ms/step - loss: 4.8938 - accuracy: 0.1081 - val_loss: 5.6802 - val_accuracy: 0.0850
# Epoch 6/200
# 258/258 [==============================] - 10s 39ms/step - loss: 4.7878 - accuracy: 0.1155 - val_loss: 5.6922 - val_accuracy: 0.0909
# Epoch 7/200
# 257/258 [============================>.] - ETA: 0s - loss: 4.7002 - accuracy: 0.1213
# Generating text after Epoch: 6 with seed:
# all i want is peace and love
#
# all i want is peace and love i scare own really long the really long hombres made world's flame world's spiel flame really long eyes flame use world's magical the really long hombres space minute really kinda forever ti tonight breathe and stands space really long meant reality long space breathe really scared reality wild really else
# 258/258 [==============================] - 12s 46ms/step - loss: 4.6999 - accuracy: 0.1213 - val_loss: 5.7170 - val_accuracy: 0.0911
# Epoch 8/200
# 258/258 [==============================] - 11s 41ms/step - loss: 4.6308 - accuracy: 0.1254 - val_loss: 5.7461 - val_accuracy: 0.0888
# Epoch 9/200
# 258/258 [==============================] - 11s 41ms/step - loss: 4.5748 - accuracy: 0.1301 - val_loss: 5.7623 - val_accuracy: 0.0918
# Epoch 10/200
# 258/258 [==============================] - ETA: 0s - loss: 4.5202 - accuracy: 0.1339
# Generating text after Epoch: 9 with seed:
# all i want is peace and love
#
# all i want is peace and love once it's the ti on meant lovely long a universe really don't reality everyone really long really long hombres really day kola balling your popular rub really scared made really med a don’t made my language really scared really long ti beyond somewhere really long the meant flame breathe really
# 258/258 [==============================] - 13s 49ms/step - loss: 4.5202 - accuracy: 0.1339 - val_loss: 5.7883 - val_accuracy: 0.0933
# Epoch 11/200
# 258/258 [==============================] - 10s 40ms/step - loss: 4.4758 - accuracy: 0.1379 - val_loss: 5.8281 - val_accuracy: 0.0898
# Epoch 12/200
# 258/258 [==============================] - 10s 40ms/step - loss: 4.4340 - accuracy: 0.1409 - val_loss: 5.8709 - val_accuracy: 0.0923
# Epoch 13/200
# 256/258 [============================>.] - ETA: 0s - loss: 4.3993 - accuracy: 0.1432
# Generating text after Epoch: 12 with seed:
# all i want is peace and love
#
# all i want is peace and love am stones ti on thrill day long somewhere world's hombres space it's somewhere really don't different a brightest that the it's hombres the really long hombres eyes hombres hombres really everyone breathe world's a sky-y-y long meant left rose different eyes her it's really glans didn't nous my don't told
# 258/258 [==============================] - 12s 46ms/step - loss: 4.3990 - accuracy: 0.1431 - val_loss: 5.8785 - val_accuracy: 0.0936
# Epoch 14/200
# 258/258 [==============================] - 11s 41ms/step - loss: 4.3628 - accuracy: 0.1478 - val_loss: 5.9182 - val_accuracy: 0.0917
# Epoch 15/200
# 258/258 [==============================] - 10s 40ms/step - loss: 4.3328 - accuracy: 0.1500 - val_loss: 5.9515 - val_accuracy: 0.0910
# Epoch 16/200
# 258/258 [==============================] - ETA: 0s - loss: 4.3031 - accuracy: 0.1529
# Generating text after Epoch: 15 with seed:
# all i want is peace and love
#
# all i want is peace and love and a touching different seek eyes space really long stars shines really long shout seek sorrows facile meant whiskey day my don't sit the world's really long hombres into ti can madly my my it's really words shout ti nobody scared stars my my long within on my my there's
# 258/258 [==============================] - 12s 46ms/step - loss: 4.3031 - accuracy: 0.1529 - val_loss: 6.0098 - val_accuracy: 0.0951
# Epoch 17/200
# 258/258 [==============================] - 10s 39ms/step - loss: 4.2776 - accuracy: 0.1544 - val_loss: 6.0272 - val_accuracy: 0.0957
# Epoch 18/200
# 258/258 [==============================] - 11s 41ms/step - loss: 4.2554 - accuracy: 0.1559 - val_loss: 6.0334 - val_accuracy: 0.0898
# Epoch 19/200
# 256/258 [============================>.] - ETA: 0s - loss: 4.2341 - accuracy: 0.1589
# Generating text after Epoch: 18 with seed:
# all i want is peace and love
#
# all i want is peace and love forever use really scared stay ti he's knew meant after really it's flame own somewhere really along seek love's shines escape really my left hos really my along the world's space it's capable my and don't has unite really long flame different sit her different shout keeps ooh don't winds
# 258/258 [==============================] - 12s 47ms/step - loss: 4.2345 - accuracy: 0.1588 - val_loss: 6.0929 - val_accuracy: 0.0923
# Epoch 20/200
# 258/258 [==============================] - 10s 41ms/step - loss: 4.2097 - accuracy: 0.1632 - val_loss: 6.1055 - val_accuracy: 0.0935
# Epoch 21/200
# 258/258 [==============================] - 10s 38ms/step - loss: 4.1940 - accuracy: 0.1639 - val_loss: 6.1176 - val_accuracy: 0.0912
# Epoch 22/200
# 257/258 [============================>.] - ETA: 0s - loss: 4.1704 - accuracy: 0.1660
# Generating text after Epoch: 21 with seed:
# all i want is peace and love
#
# all i want is peace and love on scared these own really suppose don't happy scared knew seek the my a madly calling the my med eyes the my a mama madly long any long stars shines shines into ti on my it's shines looking a madly my we my can forever my long the my us
# 258/258 [==============================] - 12s 46ms/step - loss: 4.1707 - accuracy: 0.1660 - val_loss: 6.1508 - val_accuracy: 0.0935
# Epoch 23/200
# 258/258 [==============================] - 11s 42ms/step - loss: 4.1539 - accuracy: 0.1675 - val_loss: 6.1756 - val_accuracy: 0.0952
# Epoch 24/200
# 258/258 [==============================] - 11s 43ms/step - loss: 4.1370 - accuracy: 0.1687 - val_loss: 6.1856 - val_accuracy: 0.0929
# Epoch 25/200
# 258/258 [==============================] - ETA: 0s - loss: 4.1242 - accuracy: 0.1699
# Generating text after Epoch: 24 with seed:
# all i want is peace and love
#
# all i want is peace and love and reality signs shines really this shines shines shines really alone help the really don't knew history says meant shines shines shines shines huh lights shines really dance had madly help meant shines who'll flame world's day long a madly made own peace hold he's didn't eyes parole really glassy
# 258/258 [==============================] - 13s 49ms/step - loss: 4.1242 - accuracy: 0.1699 - val_loss: 6.2206 - val_accuracy: 0.0918
# Epoch 26/200
# 258/258 [==============================] - 11s 42ms/step - loss: 4.1060 - accuracy: 0.1734 - val_loss: 6.2322 - val_accuracy: 0.0930
# Epoch 27/200
# 258/258 [==============================] - 11s 43ms/step - loss: 4.0947 - accuracy: 0.1740 - val_loss: 6.2662 - val_accuracy: 0.0960
# Epoch 28/200
# 256/258 [============================>.] - ETA: 0s - loss: 4.0818 - accuracy: 0.1751
# Generating text after Epoch: 27 with seed:
# all i want is peace and love
#
# all i want is peace and love am her my into and stars shines meant sit nous shines shines shines shines shines shines a forever my scared the my day anyway all stars summer no ti on my long seek trouble lights shines shines a balling good day it's shines super really day glassy scared lightning life
# 258/258 [==============================] - 12s 48ms/step - loss: 4.0813 - accuracy: 0.1752 - val_loss: 6.3032 - val_accuracy: 0.0922
# Epoch 29/200
# 258/258 [==============================] - 11s 42ms/step - loss: 4.0679 - accuracy: 0.1748 - val_loss: 6.3029 - val_accuracy: 0.0928
# Epoch 30/200
# 258/258 [==============================] - 11s 42ms/step - loss: 4.0578 - accuracy: 0.1774 - val_loss: 6.3272 - val_accuracy: 0.0928
# Epoch 31/200
# 257/258 [============================>.] - ETA: 0s - loss: 4.0460 - accuracy: 0.1794
# Generating text after Epoch: 30 with seed:
# all i want is peace and love
#
# all i want is peace and love am wonder really dig a circle it's shines shines shines discover really scared ti on don't don't hos meant hos shines summer really long the tame really wild a somewhere really it's shines shines hos meant different sit rainbow really words peace breathe really long the it's really my brand
# 258/258 [==============================] - 12s 47ms/step - loss: 4.0465 - accuracy: 0.1794 - val_loss: 6.3225 - val_accuracy: 0.0915
# Epoch 32/200
# 258/258 [==============================] - 11s 42ms/step - loss: 4.0336 - accuracy: 0.1806 - val_loss: 6.3688 - val_accuracy: 0.0920
# Epoch 33/200
# 258/258 [==============================] - 11s 41ms/step - loss: 4.0181 - accuracy: 0.1812 - val_loss: 6.3792 - val_accuracy: 0.0925
# Epoch 34/200
# 256/258 [============================>.] - ETA: 0s - loss: 4.0129 - accuracy: 0.1835
# Generating text after Epoch: 33 with seed:
# all i want is peace and love
#
# all i want is peace and love am he's shines music into calling shadows hoping day med shines shines trouble really help a madly anyway the really i on words shines shines shines shines shines shines shines shines shines shines shines shines hay it's shines shines peace it's shines ti on my long a madly scared lei
# 258/258 [==============================] - 12s 48ms/step - loss: 4.0127 - accuracy: 0.1835 - val_loss: 6.3986 - val_accuracy: 0.0925
# Epoch 35/200
# 258/258 [==============================] - 11s 41ms/step - loss: 4.0060 - accuracy: 0.1838 - val_loss: 6.3953 - val_accuracy: 0.0894
# Epoch 36/200
# 258/258 [==============================] - 11s 43ms/step - loss: 4.0000 - accuracy: 0.1847 - val_loss: 6.4605 - val_accuracy: 0.0952
# Epoch 37/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.9891 - accuracy: 0.1858
# Generating text after Epoch: 36 with seed:
# all i want is peace and love
#
# all i want is peace and love and shines shines shines a madly glassy my day into my help different shines shines shines shines shines shines shines shines shines shines shines peace lights shines flame minute use really words shines shines shines who'll there's shines shines shines shines shines ti on my words shines shines shines shines
# 258/258 [==============================] - 13s 49ms/step - loss: 3.9887 - accuracy: 0.1859 - val_loss: 6.4192 - val_accuracy: 0.0891
# Epoch 38/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.9773 - accuracy: 0.1871 - val_loss: 6.4883 - val_accuracy: 0.0944
# Epoch 39/200
# 258/258 [==============================] - 11s 41ms/step - loss: 3.9706 - accuracy: 0.1876 - val_loss: 6.4915 - val_accuracy: 0.0916
# Epoch 40/200
# 258/258 [==============================] - ETA: 0s - loss: 3.9582 - accuracy: 0.1897
# Generating text after Epoch: 39 with seed:
# all i want is peace and love
#
# all i want is peace and love am ooh into and day dance your lights good shines shines shines rolls seek you've really words shines shines shines shines shines shines shines against after really long a home really signs shines shines shines shines day long flame it's shines shines shines shines ooh times shines shines shines shines
# 258/258 [==============================] - 12s 47ms/step - loss: 3.9582 - accuracy: 0.1897 - val_loss: 6.4983 - val_accuracy: 0.0897
# Epoch 41/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.9527 - accuracy: 0.1896 - val_loss: 6.5422 - val_accuracy: 0.0890
# Epoch 42/200
# 258/258 [==============================] - 11s 42ms/step - loss: 3.9470 - accuracy: 0.1915 - val_loss: 6.5162 - val_accuracy: 0.0915
# Epoch 43/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.9439 - accuracy: 0.1902
# Generating text after Epoch: 42 with seed:
# all i want is peace and love
#
# all i want is peace and love am made really us shines shines times long hoping her minute really my long the really long there's who'll day anyway own he's shines day help stars her own he's shines shines shines ooh my my anyway it's shines ooh shadows shines her it's shines blowing soul day words did
# 258/258 [==============================] - 12s 48ms/step - loss: 3.9437 - accuracy: 0.1902 - val_loss: 6.5563 - val_accuracy: 0.0940
# Epoch 44/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.9363 - accuracy: 0.1903 - val_loss: 6.5800 - val_accuracy: 0.0918
# Epoch 45/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.9284 - accuracy: 0.1920 - val_loss: 6.5538 - val_accuracy: 0.0883
# Epoch 46/200
# 258/258 [==============================] - ETA: 0s - loss: 3.9213 - accuracy: 0.1933
# Generating text after Epoch: 45 with seed:
# all i want is peace and love
#
# all i want is peace and love and good shines shines shines shines shines golden really saving a forever lights shines shines shines meant sit sit shines into two ti on my stars shines blowing hoping hoping hoping good golden really help meant sit ooh ti on hold lever my long the own number really times shines
# 258/258 [==============================] - 12s 46ms/step - loss: 3.9213 - accuracy: 0.1933 - val_loss: 6.5801 - val_accuracy: 0.0948
# Epoch 47/200
# 258/258 [==============================] - 11s 41ms/step - loss: 3.9155 - accuracy: 0.1938 - val_loss: 6.6210 - val_accuracy: 0.0954
# Epoch 48/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.9102 - accuracy: 0.1948 - val_loss: 6.6139 - val_accuracy: 0.0905
# Epoch 49/200
# 258/258 [==============================] - ETA: 0s - loss: 3.9050 - accuracy: 0.1935
# Generating text after Epoch: 48 with seed:
# all i want is peace and love
#
# all i want is peace and love my the it's don't shines shines shines times shines day anyway saving hoping needing lei on my really mirror we'll day the a madly scared stars shines else and day don't after really me no my help looking made had the it's hoping hoping hoping low blues day left sit
# 258/258 [==============================] - 12s 46ms/step - loss: 3.9050 - accuracy: 0.1935 - val_loss: 6.6389 - val_accuracy: 0.0911
# Epoch 50/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.9009 - accuracy: 0.1958 - val_loss: 6.6761 - val_accuracy: 0.0933
# Epoch 51/200
# 258/258 [==============================] - 11s 41ms/step - loss: 3.8936 - accuracy: 0.1973 - val_loss: 6.6536 - val_accuracy: 0.0913
# Epoch 52/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.8885 - accuracy: 0.1963
# Generating text after Epoch: 51 with seed:
# all i want is peace and love
#
# all i want is peace and love am losing lei on shadows east sit sit sit sit sit sit sit battle own and stars seek day and day wild might sit sit sit he's shines seek lei on calling the and number awake really times shines hoping hoping you've world's don't sit sit seek day my long
# 258/258 [==============================] - 12s 47ms/step - loss: 3.8893 - accuracy: 0.1964 - val_loss: 6.6592 - val_accuracy: 0.0897
# Epoch 53/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.8806 - accuracy: 0.1976 - val_loss: 6.7013 - val_accuracy: 0.0888
# Epoch 54/200
# 258/258 [==============================] - 10s 41ms/step - loss: 3.8758 - accuracy: 0.1986 - val_loss: 6.7093 - val_accuracy: 0.0904
# Epoch 55/200
# 258/258 [==============================] - ETA: 0s - loss: 3.8761 - accuracy: 0.1992
# Generating text after Epoch: 54 with seed:
# all i want is peace and love
#
# all i want is peace and love am looking the keeps there's flame really funny words shines shines shines shines you've lights the own hoping lei into my wart he's hoping hoping looking shadows shines ooh into forever and shines ooh into my don't ooh and shines my don't ooh two my hon and shines hearts shines
# 258/258 [==============================] - 12s 47ms/step - loss: 3.8761 - accuracy: 0.1992 - val_loss: 6.7157 - val_accuracy: 0.0943
# Epoch 56/200
# 258/258 [==============================] - 10s 38ms/step - loss: 3.8701 - accuracy: 0.2003 - val_loss: 6.7064 - val_accuracy: 0.0887
# Epoch 57/200
# 258/258 [==============================] - 11s 41ms/step - loss: 3.8699 - accuracy: 0.1998 - val_loss: 6.7204 - val_accuracy: 0.0876
# Epoch 58/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.8608 - accuracy: 0.2002
# Generating text after Epoch: 57 with seed:
# all i want is peace and love
#
# all i want is peace and love am a madly anyway help golden really help shines shines shines shines shines shines shines ooh two hay and shines shines shines shines shines shines number into really help else lights shines else and shines shines shines shines seek lei on my anyway tutti my strong looking the lights shines
# 258/258 [==============================] - 12s 47ms/step - loss: 3.8605 - accuracy: 0.2003 - val_loss: 6.7517 - val_accuracy: 0.0940
# Epoch 59/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.8555 - accuracy: 0.2020 - val_loss: 6.7087 - val_accuracy: 0.0890
# Epoch 60/200
# 258/258 [==============================] - 11s 42ms/step - loss: 3.8519 - accuracy: 0.2031 - val_loss: 6.7584 - val_accuracy: 0.0936
# Epoch 61/200
# 258/258 [==============================] - ETA: 0s - loss: 3.8476 - accuracy: 0.2016
# Generating text after Epoch: 60 with seed:
# all i want is peace and love
#
# all i want is peace and love hep that shines lips shines shines shines shines shines ti on meant shines shines crazy lass ooh into my med shines shines shines shines shines didn't sit shines shines shines shines shines shines seek lei the really anyway into my anyway help wonder and shines shines shines shines shines shines
# 258/258 [==============================] - 12s 45ms/step - loss: 3.8476 - accuracy: 0.2016 - val_loss: 6.7424 - val_accuracy: 0.0907
# Epoch 62/200
# 258/258 [==============================] - 11s 42ms/step - loss: 3.8431 - accuracy: 0.2035 - val_loss: 6.7471 - val_accuracy: 0.0886
# Epoch 63/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.8417 - accuracy: 0.2040 - val_loss: 6.7822 - val_accuracy: 0.0941
# Epoch 64/200
# 258/258 [==============================] - ETA: 0s - loss: 3.8365 - accuracy: 0.2035
# Generating text after Epoch: 63 with seed:
# all i want is peace and love
#
# all i want is peace and love hep my times shines shines shines shines shines shines shines shines shines shines shines shines shines shines shines parole really my kinda madly day help shines shines shines no hold shines shines shines shines shines shines shines shines shines shines shines shines soul you've it's shines shines shines shines shines
# 258/258 [==============================] - 13s 49ms/step - loss: 3.8365 - accuracy: 0.2035 - val_loss: 6.7750 - val_accuracy: 0.0918
# Epoch 65/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.8372 - accuracy: 0.2029 - val_loss: 6.7902 - val_accuracy: 0.0924
# Epoch 66/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.8313 - accuracy: 0.2045 - val_loss: 6.8089 - val_accuracy: 0.0896
# Epoch 67/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.8259 - accuracy: 0.2041
# Generating text after Epoch: 66 with seed:
# all i want is peace and love
#
# all i want is peace and love on my a madly words shines shines shines hoping hoping hoping knew he's shines shines shadows shines shines shines shines shines day times ti yeah forever made really med shines shines shines shines my anyway anyway anyway words he's shines peace really else really anyway and shines shines shines shines
# 258/258 [==============================] - 12s 47ms/step - loss: 3.8253 - accuracy: 0.2041 - val_loss: 6.8292 - val_accuracy: 0.0923
# Epoch 68/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.8204 - accuracy: 0.2055 - val_loss: 6.7918 - val_accuracy: 0.0883
# Epoch 69/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.8238 - accuracy: 0.2046 - val_loss: 6.8305 - val_accuracy: 0.0906
# Epoch 70/200
# 258/258 [==============================] - ETA: 0s - loss: 3.8141 - accuracy: 0.2066
# Generating text after Epoch: 69 with seed:
# all i want is peace and love
#
# all i want is peace and love i on lass shines shines shines shines shines shines shines seek the believe minute and shines shines shines shines shines shines shines shines shines number no two ti on into my along lei faith sit sit shines he's shines shines shines shines shines shines shines shines didn't another really help
# 258/258 [==============================] - 12s 47ms/step - loss: 3.8141 - accuracy: 0.2066 - val_loss: 6.8357 - val_accuracy: 0.0896
# Epoch 71/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.8150 - accuracy: 0.2062 - val_loss: 6.8554 - val_accuracy: 0.0919
# Epoch 72/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.8142 - accuracy: 0.2057 - val_loss: 6.8491 - val_accuracy: 0.0914
# Epoch 73/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.8098 - accuracy: 0.2073
# Generating text after Epoch: 72 with seed:
# all i want is peace and love
#
# all i want is peace and love hep shines shines shines looking hoping the similar forever forever made made really wild shines shines shines shines shines shines shines shines shines shines shines shines shines shines shines shines shines shines shines shines golden really left shines shines shines shines shines shines shines shines shines shines shines shines shines
# 258/258 [==============================] - 12s 46ms/step - loss: 3.8097 - accuracy: 0.2073 - val_loss: 6.8841 - val_accuracy: 0.0948
# Epoch 74/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.8075 - accuracy: 0.2074 - val_loss: 6.8728 - val_accuracy: 0.0914
# Epoch 75/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.8000 - accuracy: 0.2079 - val_loss: 6.8771 - val_accuracy: 0.0902
# Epoch 76/200
# 258/258 [==============================] - ETA: 0s - loss: 3.8015 - accuracy: 0.2073
# Generating text after Epoch: 75 with seed:
# all i want is peace and love
#
# all i want is peace and love on my you's these really dial shadows shines shines my help shines my you's golden midsummer made forever wonder really anyway my anyway anyway help shines shines shines shines and shines shines shines shines he's my long the lights shines shines shines shines shines shines shines shines shines shines day
# 258/258 [==============================] - 12s 47ms/step - loss: 3.8015 - accuracy: 0.2073 - val_loss: 6.8972 - val_accuracy: 0.0911
# Epoch 77/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.7958 - accuracy: 0.2087 - val_loss: 6.8970 - val_accuracy: 0.0937
# Epoch 78/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7959 - accuracy: 0.2083 - val_loss: 6.9125 - val_accuracy: 0.0879
# Epoch 79/200
# 256/258 [============================>.] - ETA: 0s - loss: 3.7882 - accuracy: 0.2103
# Generating text after Epoch: 78 with seed:
# all i want is peace and love
#
# all i want is peace and love on into into awake and shines he's shines golden and golden made lights history funny help lei on a whoa madly mirror into chance made a circle brand vol flame made made different sit after made universe and day day and flame lights shines shines shines shines shines shines he's
# 258/258 [==============================] - 12s 45ms/step - loss: 3.7888 - accuracy: 0.2103 - val_loss: 6.8978 - val_accuracy: 0.0909
# Epoch 80/200
# 258/258 [==============================] - 11s 41ms/step - loss: 3.7886 - accuracy: 0.2094 - val_loss: 6.9174 - val_accuracy: 0.0939
# Epoch 81/200
# 258/258 [==============================] - 11s 41ms/step - loss: 3.7846 - accuracy: 0.2096 - val_loss: 6.9182 - val_accuracy: 0.0856
# Epoch 82/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.7828 - accuracy: 0.2117
# Generating text after Epoch: 81 with seed:
# all i want is peace and love
#
# all i want is peace and love hep my wild shines he's seek the lights shines shines shines shines shines you've now he's flame awake my help don't shines shines shines shines shines good shines shines shines shines shines the and vol flame lights shines shines shines shines shines shines no the too forever minute somewhere somewhere
# 258/258 [==============================] - 12s 47ms/step - loss: 3.7832 - accuracy: 0.2115 - val_loss: 6.9173 - val_accuracy: 0.0904
# Epoch 83/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.7833 - accuracy: 0.2113 - val_loss: 6.9587 - val_accuracy: 0.0917
# Epoch 84/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7780 - accuracy: 0.2113 - val_loss: 6.9958 - val_accuracy: 0.0958
# Epoch 85/200
# 258/258 [==============================] - ETA: 0s - loss: 3.7766 - accuracy: 0.2122
# Generating text after Epoch: 84 with seed:
# all i want is peace and love
#
# all i want is peace and love jew he's shines he's lei faith shines shines shines number yo my help lei on help he's shines her it's shines shines shines shines shines shines shines shines shines shines shines shines shines shines shines good vol flame lass shines shines these lights day don't shines he's he's seek low
# 258/258 [==============================] - 12s 47ms/step - loss: 3.7766 - accuracy: 0.2122 - val_loss: 6.9419 - val_accuracy: 0.0901
# Epoch 86/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7728 - accuracy: 0.2115 - val_loss: 6.9635 - val_accuracy: 0.0878
# Epoch 87/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7750 - accuracy: 0.2120 - val_loss: 6.9717 - val_accuracy: 0.0900
# Epoch 88/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.7658 - accuracy: 0.2128
# Generating text after Epoch: 87 with seed:
# all i want is peace and love
#
# all i want is peace and love forever you've made really into uh lights shines shines shines shines shines shines he's the made est shines lei on two meant shines shines shines don't shines shines shines shines shines hay my anyway anyway into my these somewhere meant shines the day long flame lights ooh day peace tame
# 258/258 [==============================] - 12s 45ms/step - loss: 3.7660 - accuracy: 0.2128 - val_loss: 6.9457 - val_accuracy: 0.0915
# Epoch 89/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.7675 - accuracy: 0.2133 - val_loss: 6.9514 - val_accuracy: 0.0908
# Epoch 90/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7621 - accuracy: 0.2143 - val_loss: 7.0042 - val_accuracy: 0.0894
# Epoch 91/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.7601 - accuracy: 0.2140
# Generating text after Epoch: 90 with seed:
# all i want is peace and love
#
# all i want is peace and love hep shines soldiers shines stars shines her my help seek blues he's shines my it's shines hold flame the wonder the day day help shines these really anyway hold shines he's shines shines shines my anyway anyway anyway now he's seek lei on into my anyway hon don't shines shines
# 258/258 [==============================] - 12s 47ms/step - loss: 3.7602 - accuracy: 0.2141 - val_loss: 6.9796 - val_accuracy: 0.0917
# Epoch 92/200
# 258/258 [==============================] - 11s 42ms/step - loss: 3.7579 - accuracy: 0.2144 - val_loss: 6.9940 - val_accuracy: 0.0922
# Epoch 93/200
# 258/258 [==============================] - 10s 38ms/step - loss: 3.7585 - accuracy: 0.2127 - val_loss: 7.0577 - val_accuracy: 0.0959
# Epoch 94/200
# 256/258 [============================>.] - ETA: 0s - loss: 3.7542 - accuracy: 0.2147
# Generating text after Epoch: 93 with seed:
# all i want is peace and love
#
# all i want is peace and love jew hoping lei faith sit shines made around shines shines you've fem music faith strong my into into into into lights shines shines shines shines lei on made fem made really really into lights he's her around shines hold where's lei on into and vol flame really lass shines lei
# 258/258 [==============================] - 12s 48ms/step - loss: 3.7533 - accuracy: 0.2148 - val_loss: 7.0244 - val_accuracy: 0.0892
# Epoch 95/200
# 258/258 [==============================] - 11s 41ms/step - loss: 3.7572 - accuracy: 0.2136 - val_loss: 7.0098 - val_accuracy: 0.0873
# Epoch 96/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.7519 - accuracy: 0.2148 - val_loss: 7.0479 - val_accuracy: 0.0902
# Epoch 97/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.7496 - accuracy: 0.2148
# Generating text after Epoch: 96 with seed:
# all i want is peace and love
#
# all i want is peace and love on into chance made keeps he's my your these and shines her other made fem you've minute lights hold flame forever forever mirror really hold shines a madly help lei on alone made really the really these made really strong flame it's he's lei on hay help lei on hay
# 258/258 [==============================] - 12s 48ms/step - loss: 3.7494 - accuracy: 0.2148 - val_loss: 7.0376 - val_accuracy: 0.0893
# Epoch 98/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7458 - accuracy: 0.2152 - val_loss: 7.0123 - val_accuracy: 0.0875
# Epoch 99/200
# 258/258 [==============================] - 11s 41ms/step - loss: 3.7440 - accuracy: 0.2159 - val_loss: 7.0182 - val_accuracy: 0.0892
# Epoch 100/200
# 258/258 [==============================] - ETA: 0s - loss: 3.7478 - accuracy: 0.2153
# Generating text after Epoch: 99 with seed:
# all i want is peace and love
#
# all i want is peace and love hep lei faith shines shines my the believe meant shines day it's he's parole forever forever similar madly help lei no really no my day help lei on my really funny my funny funny help lei on really funny all flame forever made really help he's lei faith shines he's
# 258/258 [==============================] - 12s 46ms/step - loss: 3.7478 - accuracy: 0.2153 - val_loss: 7.0574 - val_accuracy: 0.0910
# Epoch 101/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7401 - accuracy: 0.2165 - val_loss: 7.0346 - val_accuracy: 0.0886
# Epoch 102/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7428 - accuracy: 0.2152 - val_loss: 7.0578 - val_accuracy: 0.0946
# Epoch 103/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.7395 - accuracy: 0.2166
# Generating text after Epoch: 102 with seed:
# all i want is peace and love
#
# all i want is peace and love i on forever different shines shines my funny a madly peace falter really day anyway my anyway help low shines my med now hold shines my into meant shines the minute made minute made really and music on my anyway and shines lei no into times shines shines shines shines
# 258/258 [==============================] - 12s 46ms/step - loss: 3.7397 - accuracy: 0.2165 - val_loss: 7.0405 - val_accuracy: 0.0904
# Epoch 104/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7375 - accuracy: 0.2174 - val_loss: 7.0353 - val_accuracy: 0.0923
# Epoch 105/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.7338 - accuracy: 0.2180 - val_loss: 7.0668 - val_accuracy: 0.0910
# Epoch 106/200
# 258/258 [==============================] - ETA: 0s - loss: 3.7300 - accuracy: 0.2184
# Generating text after Epoch: 105 with seed:
# all i want is peace and love
#
# all i want is peace and love we made lights day and shines he's hay into into calling lei on forever really into into stone really anyway into day hold shines he's the really help lei faith shines he's shines had made really help he's hold shines shines shines he's he's shines he's he's shines shines flame
# 258/258 [==============================] - 12s 46ms/step - loss: 3.7300 - accuracy: 0.2184 - val_loss: 7.0773 - val_accuracy: 0.0889
# Epoch 107/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7309 - accuracy: 0.2176 - val_loss: 7.0944 - val_accuracy: 0.0955
# Epoch 108/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.7352 - accuracy: 0.2161 - val_loss: 7.1247 - val_accuracy: 0.0916
# Epoch 109/200
# 258/258 [==============================] - ETA: 0s - loss: 3.7278 - accuracy: 0.2193
# Generating text after Epoch: 108 with seed:
# all i want is peace and love
#
# all i want is peace and love me made lights a forever lights he's he's my hold flame really left he's my long lei on care forever fem flame minute and made minute really anyway strong lei on three and flame fem made minute made and lei alone made minute awake minute made made around times my
# 258/258 [==============================] - 12s 46ms/step - loss: 3.7278 - accuracy: 0.2193 - val_loss: 7.0930 - val_accuracy: 0.0895
# Epoch 110/200
# 258/258 [==============================] - 10s 40ms/step - loss: 3.7222 - accuracy: 0.2177 - val_loss: 7.0959 - val_accuracy: 0.0929
# Epoch 111/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.7255 - accuracy: 0.2179 - val_loss: 7.0785 - val_accuracy: 0.0916
# Epoch 112/200
# 257/258 [============================>.] - ETA: 0s - loss: 3.7236 - accuracy: 0.2186
# Generating text after Epoch: 111 with seed:
# all i want is peace and love
#
# all i want is peace and love on care really into and lei faith low he's drink lei on these different day shadows lei faith seek made lights lei faith golden made and flame really into my funny into forever and golden forever fem flame somewhere forever forever made own he's he's shines my else forever falter
# 258/258 [==============================] - 12s 45ms/step - loss: 3.7233 - accuracy: 0.2187 - val_loss: 7.1129 - val_accuracy: 0.0883
# Epoch 113/200
# 258/258 [==============================] - 10s 39ms/step - loss: 3.7221 - accuracy: 0.2199 - val_loss: 7.0939 - val_accuracy: 0.0934
# Epoch 00113: early stopping

# %%
with open('./history', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)

# %%
model.save('./model')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ./model_tues/assets
